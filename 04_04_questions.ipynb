# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('flower.jpg')
plt.subplot(2,3,1)
plt.title("Original")
plt.imshow(image)

gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
plt.subplot(2,3,2)
plt.title("Grayscale")
plt.imshow(gray_image, cmap = 'gray')

_, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
plt.subplot(2,3,3)
plt.title("Binary")
plt.imshow(binary_image, cmap = 'gray')

blue_channel, green_channel, red_channel = cv2.split(image)

plt.subplot(2,3,4)
plt.title('Red Channel')
plt.imshow(red_channel, cmap = 'Reds')

plt.subplot(2,3,5)
plt.title('Green Channel')
plt.imshow(green_channel, cmap='Greens')

plt.subplot(2,3,6)
plt.title('Blue Channel')
plt.imshow(blue_channel, cmap='Blues')

# %%
import cv2
import numpy as np

img = cv2.imread("sunflower.jpg")

# Convert the image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Get image dimensions
height, width = gray_img.shape

# Calculate the coordinates of the center pixel
center_x, center_y = width // 2, height // 2

# Calculate Euclidean distance between each pixel and the center
distances = np.zeros((height, width), dtype=np.float32)
for i in range(height):
    for j in range(width):
        distances[i, j] = np.sqrt((i - center_y)**2 + (j - center_x)**2)

# Normalize distances to range [0, 255] for visualization
distances_normalized = cv2.normalize(distances, None, 0, 255, cv2.NORM_MINMAX)

# Display the distance map
cv2.imshow('Distance Map', distances_normalized.astype(np.uint8))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Read the images
img1 = cv2.imread("flower.jpg")
img2 = cv2.imread("sunflower.jpg")

# Ensure images have the same dimensions
height, width, _ = img1.shape
img2 = cv2.resize(img2, (width, height))

# Convert images to grayscale
gray_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# Compute the absolute difference between corresponding pixels
pixel_diff = np.abs(gray_img1 - gray_img2)
print(pixel_diff)

# Display the pixel difference map
cv2.imshow('Pixel Difference Map', pixel_diff.astype(np.uint8))
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[ 47  47  47 ... 207 207 207]
#  [ 47  47  47 ... 204 204 204]
#  [ 47  47  47 ... 202 202 201]
#  ...
#  [187 185 185 ... 204 222 237]
#  [189 184 183 ... 207 225 238]
#  [191 184 182 ... 209 224 236]]

# %%
import cv2
import numpy as np

# Read the image
img = cv2.imread("bird.jpg", cv2.IMREAD_GRAYSCALE)

# Calculate mean and standard deviation
mean_value = np.mean(img)
std_deviation = np.std(img)

# Calculate correlation coefficient
correlation_coefficient = np.corrcoef(img)[0, 1]

# Display results
print("Mean: {:.2f}".format(mean_value))
print("Standard Deviation: {:.2f}".format(std_deviation))
print("Correlation Coefficient: {:.2f}".format(correlation_coefficient))
# Out:
# Mean: 167.01
# Standard Deviation: 39.13
# Correlation Coefficient: 0.99

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread("dog.jpg", cv2.IMREAD_GRAYSCALE)

# Iterate through each bit plane
for i in range(8):
    # Extract the i-th bit plane
    bit_plane = (img >> i) & 1

    # Display the bit plane
    plt.subplot(2, 4, i+1)
    plt.imshow(bit_plane, cmap='gray')
    plt.title(f'Bit Plane {i}')
    plt.axis('off')

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image =cv2.imread('flower.jpg')

# Convert BGR image to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Define the scale factor
# Increase the size by 3 times
scale_factor_1 = 3.0  
# Decrease the size by 3 times
scale_factor_2 = 1/3.0

# Get the original image dimensions
height, width = image_rgb.shape[:2]

# Calculate the new image dimensions
new_height = int(height * scale_factor_1)
new_width = int(width * scale_factor_1)

# Resize the image
zoomed_image = cv2.resize(src =image_rgb, 
                          dsize=(new_width, new_height), 
                          interpolation=cv2.INTER_CUBIC)

# Calculate the new image dimensions
new_height1 = int(height * scale_factor_2)
new_width1 = int(width * scale_factor_2)

# Scaled image
scaled_image = cv2.resize(src= image_rgb, 
                          dsize =(new_width1, new_height1), 
                          interpolation=cv2.INTER_AREA)

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(10, 4))

# Plot the original image
axs[0].imshow(image_rgb)
axs[0].set_title('Original Image Shape:'+str(image_rgb.shape))

# Plot the Zoomed Image
axs[1].imshow(zoomed_image)
axs[1].set_title('Zoomed Image Shape:'+str(zoomed_image.shape))

# Plot the Scaled Image
axs[2].imshow(scaled_image)
axs[2].set_title('Scaled Image Shape:'+str(scaled_image.shape))

# Remove ticks from the subplots
for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

# Display the subplots
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread("ganesha.png", cv2.IMREAD_GRAYSCALE)

low_threshold = 100  
high_threshold = 200 

# Apply intensity slicing
result_img = np.zeros_like(img)
result_img[(img >= low_threshold) & (img <= high_threshold)] = 255

# Plot the original and result images using Matplotlib
plt.figure(figsize=(5, 3))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')

# Enhanced image
plt.subplot(1, 2, 2)
plt.imshow(result_img, cmap='gray')
plt.title('Enhanced Image')

plt.tight_layout()
plt.show()

# %%
import cv2 
import matplotlib.pyplot as plt 
import numpy as np 

# Load the image 
image = cv2.imread('cat.jpg') 

#Plot the original image 
plt.subplot(1, 2, 1) 
plt.title("Original") 
plt.imshow(image) 

# Remove noise using a median filter 
filtered_image = cv2.medianBlur(image, 11) 

#Save the image 
cv2.imwrite('Median Blur.jpg', filtered_image) 

#Plot the blured image 
plt.subplot(1, 2, 2) 
plt.title("Median Blur") 
plt.imshow(filtered_image) 
plt.show()
